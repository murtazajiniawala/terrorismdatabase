# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import os
for dirname, _, filenames in os.walk('E:\Courses\Kaggle'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data = pd.read_csv("/kaggle/input/gtd/globalterrorismdb_0718dist.csv", engine='python')
data.head()

# %%
data.info()

# %%
col_names = data.columns.values.tolist()
col_names

# %%
data[col_names[0:60]].isnull().sum()

# %%
data[col_names[61:120]].isnull().sum()

# %%
data[col_names[121:135]].isnull().sum()

# %% [markdown]
# Create a new dataset with non null columns

# %%
col_notnull_names = data.columns[data.isnull().sum()<=100000]

df = pd.DataFrame(data[col_notnull_names], columns = col_notnull_names)
df.head()
